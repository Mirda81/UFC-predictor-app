# %%
import pandas as pd

df_skills = pd.read_csv('df_skills.csv')
df_fight_stats = pd.read_csv('fight_with_stats.csv')
import numpy as np

# %%
fighter = 'Khabib Nurmagomedov'

def skills(fighter_name):
    df_fighter = df_skills[df_skills['FIGHTER']==fighter_name]
    df_fighter_stats = df_fight_stats[df_fight_stats['FIGHTER']==fighter_name]
    pocet_zapasu = df_fighter['Fights']
    celkovy_cas = df_fighter['TotalTime']
    cas_na_nohach = celkovy_cas - df_fighter["CTRL_fighter"]-df_fighter['CTRL_opponent']
    def ground_skills_def():        
        pocet_prohrani_na_sub = int(df_fighter['Lost-ground'])
        pomer_prohranych_sub = float(pocet_prohrani_na_sub/pocet_zapasu)
        cas_na_zadech = int(df_fighter['CTRL_opponent'])
        koef_zada = cas_na_zadech/celkovy_cas
        g_a_p_deff = (df_fighter['GROUND_landed_opponent']/df_fighter['GROUND_attemps_opponent'])*koef_zada
        takedown_def = (df_fighter['TD_landed_opponent']/df_fighter['TD_attemps_opponent'])
        reversal_skill = float(df_fighter["REV._fighter"]/pocet_zapasu)
        ground_skills_def = (takedown_def+ reversal_skill - (pomer_prohranych_sub*2)+g_a_p_deff)*(1-koef_zada)
        return float(ground_skills_def) if float(ground_skills_def) > 0 else 0 

    def ground_skills_att():
        pocet_vyher_na_sub = int(df_fighter['Win-ground'])
        pomer_vyher_sub = pocet_vyher_na_sub/pocet_zapasu
        koef_vyher_sub = (pomer_vyher_sub)

        koef_kontroly = float((1-(df_fighter['CTRL_fighter']/celkovy_cas)))

        g_a_p = float(df_fighter['GROUND_landed_fighter'] /celkovy_cas)
        takedown_att = (df_fighter['TD_attemps_fighter'] - df_fighter['TD_landed_opponent'])/pocet_zapasu/100

        ground_skills_att = (takedown_att+ g_a_p + (koef_vyher_sub*2))/koef_kontroly
        #return (takedown_att,g_a_p, koef_vyher_sub, koef_kontroly, celkovy_skill)
        return float(ground_skills_att) if float(ground_skills_att) > 0 else 0 
    
    def standing_skills_att():
        pocet_vyher_na_ko = df_fighter["Win-striking"]
        pomer_vyher_ko = pocet_vyher_na_ko/pocet_zapasu   
        koef_nohy = cas_na_nohach/celkovy_cas
        ground_strikes = df_fighter['GROUND_attemps_fighter']

        sig_strikes_eff = (df_fighter["SIG.STR._landed_fighter"]-ground_strikes)/cas_na_nohach
        hand_speed =(df_fighter["TOTAL STR._attemps_fighter"] - ground_strikes)/cas_na_nohach
        clinch = df_fighter["CLINCH_landed_fighter"]/cas_na_nohach/(df_fighter["CLINCH_landed_fighter"]/df_fighter["CLINCH_attemps_fighter"])/100
        accuracy = ((df_fighter["TOTAL STR._landed_fighter"]/df_fighter["TOTAL STR._attemps_fighter"]) + (df_fighter["DISTANCE_landed_fighter"]/df_fighter["DISTANCE_attemps_fighter"]))/200
        celkovy_skill = (clinch+(pomer_vyher_ko*2*koef_nohy) + (sig_strikes_eff+hand_speed+accuracy)/3)
        #return (takedown_att,g_a_p, koef_vyher_sub, koef_kontroly, celkovy_skill)
        return float(celkovy_skill) if float(celkovy_skill) > 0 else 0 
    
    def standing_skills_def():
    
        pocet_proher_na_ko = pocet_vyher_na_ko = df_fighter["Lost-striking"]
        pomer_proher_ko = pocet_vyher_na_ko/pocet_zapasu      

        koef_nohy = cas_na_nohach/celkovy_cas    

        sig_strikes_def = (df_fighter['SIG.STR._attemps_opponent']-df_fighter['SIG.STR._landed_opponent'])/pocet_zapasu/100
        clinch_strikes_def =(df_fighter["CLINCH_attemps_opponent"]-df_fighter["CLINCH_attemps_opponent"])/pocet_zapasu/100     
        distance_strikes_def = (df_fighter["DISTANCE_attemps_opponent"]-df_fighter["CLINCH_attemps_opponent"])/pocet_zapasu/100    
        celkovy_skill = (clinch_strikes_def-pomer_proher_ko*2 + sig_strikes_def+distance_strikes_def)*koef_nohy
        #return (takedown_att,g_a_p, koef_vyher_sub, koef_kontroly, celkovy_skill)
        return float(celkovy_skill) if float(celkovy_skill) > 0 else 0

    def stamina():
        pocet_vyher_second_round= df_fighter_stats["Win"][(df_fighter_stats["TotalTime"]>300 )& (df_fighter_stats["TotalTime"]<=600)].sum()
        pocet_vyher_third_round= df_fighter_stats["Win"][(df_fighter_stats["TotalTime"]>600 )& (df_fighter_stats["TotalTime"]<=900)].sum()
        pocet_vyher_champ_round= df_fighter_stats["Win"][(df_fighter_stats["TotalTime"]>900 )].sum()

        pocet_zapasu_second_round= df_fighter_stats["Win"][(df_fighter_stats["TotalTime"]>300 )& (df_fighter_stats["TotalTime"]<=600)].count()
        pocet_zapasu_third_round= df_fighter_stats["Win"][(df_fighter_stats["TotalTime"]>600 )& (df_fighter_stats["TotalTime"]<=900)].count()
        pocet_zapasu_champ_round= df_fighter_stats["Win"][(df_fighter_stats["TotalTime"]>900 )].count()

        pocet_zapasu_second_round = pocet_zapasu_second_round if pocet_zapasu_second_round >0 else 1
        pocet_zapasu_third_round = pocet_zapasu_third_round if pocet_zapasu_third_round >0 else 1
        pocet_zapasu_champ_round = pocet_zapasu_champ_round if pocet_zapasu_champ_round >0 else 1

        celkovy_skill = np.array([(0.2*pocet_vyher_second_round/pocet_zapasu_second_round),(0.4*pocet_vyher_third_round/pocet_zapasu_third_round),(0.6*pocet_vyher_champ_round/pocet_zapasu_champ_round)])
         #celkovy_skill = np.nan_to_num(celkovy_skill)
        return celkovy_skill.sum()

    return(ground_skills_def(),ground_skills_att(),standing_skills_att(),standing_skills_def(),stamina())

# %%
skills(fighter)
# Out:
# (0.16386413890341198,
#  2.696691543115484,
#  0.11518631178296437,
#  0.4526235877549498,
#  1.2000000000000002)

# %%
df_skills[["ground_def_skill","ground_att_skill", "stand_def_skill","stand_att_skill", "stamina"]] = df_skills["FIGHTER"].apply(skills).apply(pd.Series).astype(float)

# %%
df_skills[["ground_def_skill","ground_att_skill", "stand_def_skill","stand_att_skill", "stamina"]].describe()
# Out:
#        ground_def_skill  ground_att_skill  stand_def_skill  stand_att_skill  \
# count       2306.000000       2306.000000      2306.000000      2306.000000
# mean           0.283688          0.391368         0.203139         0.457805
# std            0.324051          1.325884         0.213485         0.535368
# min            0.000000          0.000000         0.000000         0.000000
# 25%            0.000000          0.005646         0.084812         0.045752
# 50%            0.210519          0.061756         0.137392         0.297563
# 75%            0.471748          0.526599         0.266991         0.668534
# max            4.491875         54.242024         2.075629         4.020000
#
#            stamina
# count  2306.000000
# mean      0.202049
# std       0.231276
# min       0.000000
# 25%       0.000000
# 50%       0.160000
# 75%       0.333333
# max       1.200000

# %%
from sklearn import preprocessing
fighters_normalized = df_skills[['FIGHTER',"ground_def_skill","ground_att_skill", "stand_def_skill","stand_att_skill", "stamina"]].copy()
fighters_normalized.iloc[:,1:] =  preprocessing.normalize(fighters_normalized.iloc[:,1:])
fighters_normalized.iloc[:,1:]=fighters_normalized.iloc[:,1:].apply(lambda x:round(x*100,0)) 
fighters_normalized = fighters_normalized.set_index('FIGHTER')
fighters_normalized.describe()
# Out:
#        ground_def_skill  ground_att_skill  stand_def_skill  stand_att_skill  \
# count       2306.000000       2306.000000      2306.000000      2306.000000
# mean          29.790980         30.744579        27.923244        46.516045
# std           30.857599         34.663605        27.367519        36.035509
# min            0.000000          0.000000         0.000000         0.000000
# 25%            0.000000          1.000000         8.000000         8.250000
# 50%           22.000000         12.000000        18.000000        45.000000
# 75%           51.000000         61.000000        39.000000        81.000000
# max          100.000000        100.000000       100.000000       100.000000
#
#            stamina
# count  2306.000000
# mean     19.920208
# std      22.221614
# min       0.000000
# 25%       0.000000
# 50%      14.000000
# 75%      34.000000
# max      99.000000

# %%
fighters_normalized
# Out:
#                   ground_def_skill  ground_att_skill  stand_def_skill  \
# FIGHTER
# AJ Dobson                     64.0               0.0             34.0
# AJ Fletcher                   82.0               3.0             12.0
# Aalon Cruz                     0.0              17.0              0.0
# Aaron Brink                    0.0               0.0              0.0
# Aaron Phillips                46.0               0.0             87.0
# ...                            ...               ...              ...
# Zhang Lipeng                  71.0              14.0             35.0
# Zhang Tiequan                 41.0              91.0              0.0
# Zhang Weili                   37.0              40.0             30.0
# Zubaira Tukhugov              14.0              23.0             19.0
# Zviad Lazishvili               0.0               3.0              4.0
#
#                   stand_att_skill  stamina
# FIGHTER
# AJ Dobson                    69.0      0.0
# ...

# %%
fighter = 'Khabib Nurmagomedov'
opponent = 'Conor McGregor'

# %%
fighters_normalized.loc[opponent].values.flatten().tolist()
# Out:
# [18.0, 14.0, 60.0, 39.0, 66.0]

# %%
categories
# Out:
# ['ground_def_skill',
#  'ground_att_skill',
#  'stand_def_skill',
#  'stand_att_skill',
#  'stamina']

# %%
def chart(values1, values2):
    import matplotlib.pyplot as plt

    # Define the categories and values
    categories = ['ground_def_skill', 'ground_att_skill', 'stand_def_skill', 'stand_att_skill', 'stamina']
    


    # Create the figure
    fig = plt.figure()
    ax = fig.add_subplot(111, polar=True,facecolor='yellow')

    # Plot the data
    ax.plot(np.linspace(0, 2*np.pi, len(categories), endpoint=False), values1, 'o-', linewidth=1, color='red')
    ax.plot(np.linspace(0, 2*np.pi, len(categories), endpoint=False), values2, 'o-', linewidth=1, color='blue')
    ax.fill(np.linspace(0, 2*np.pi, len(categories), endpoint=False), values1, alpha=0.5, color='red')
    ax.fill(np.linspace(0, 2*np.pi, len(categories), endpoint=False), values2, alpha=0.5, color='blue')

    # Add labels
    ax.set_thetagrids(np.linspace(0, 360, len(categories), endpoint=False), categories, color='red')
    ax.grid(color='black')
    for spine in ax.spines.values():
        spine.set_edgecolor('black')
    # Show the plot
    return ax,plt

v1 = fighters_normalized.loc[fighter].values.flatten().tolist()
v2 = fighters_normalized.loc[opponent].values.flatten().tolist()
a,p = chart(v1,v2)
p.show()
